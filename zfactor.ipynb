# %%
from nba_api.stats.static import players
from nba_api.stats.endpoints import playergamelog, playercareerstats, cumestatsplayer, boxscoreadvancedv3, playerestimatedmetrics,commonplayerinfo

# %%
def get_player_id(player_name):
    player = players.find_players_by_full_name(player_name)
    return player[0]['id']

# %%
def player_career_stats(player_name):
    if player_name:
        player_id = get_player_id(player_name)
        data = playercareerstats.PlayerCareerStats(player_id=player_id).get_data_frames()[0]
        return data
    return None

def get_players_adv_metrics(player_name):
    data = playerestimatedmetrics.PlayerEstimatedMetrics(season='2023-24').get_data_frames()[0]
    player = get_player_id(player_name)
    return data.loc[data['PLAYER_ID'] == player]

# %%
get_players_adv_metrics('devin booker')
# Out:
#      PLAYER_ID   PLAYER_NAME  GP   W   L  W_PCT   MIN  E_OFF_RATING  \
# 267    1626164  Devin Booker  68  43  25  0.632  36.0         117.8
#
#      E_DEF_RATING  E_NET_RATING  ...  E_OFF_RATING_RANK  E_DEF_RATING_RANK  \
# 267         112.4           5.4  ...                 61                291
#
#      E_NET_RATING_RANK  E_AST_RATIO_RANK  E_OREB_PCT_RANK  E_DREB_PCT_RANK  \
# 267                114               167              382              394
#
#      E_REB_PCT_RANK  E_TOV_PCT_RANK  E_USG_PCT_RANK  E_PACE_RANK
# 267             390              48              24          268
#
# [1 rows x 32 columns]

# %%
playerestimatedmetrics.PlayerEstimatedMetrics(season='2023-24').get_data_frames()[0]
# Out:
#      PLAYER_ID         PLAYER_NAME  GP  W  L  W_PCT  MIN  E_OFF_RATING  \
# 0      1631199      Ron Harper Jr.   1  1  0  1.000  3.7         100.0
# 1      1631167  Izaiah Brockington   1  1  0  1.000  3.4         127.1
# 2      1641926       Dexter Dennis   4  1  3  0.250  7.5          89.9
# 3      1630563        Joshua Primo   2  2  0  1.000  5.1          96.7
# 4      1630535      Greg Brown III   6  3  3  0.500  6.6         105.2
# ..         ...                 ...  .. .. ..    ...  ...           ...
# 567    1628391         D.J. Wilson   2  1  1  0.500  7.7         130.8
# 568    1631250          Pete Nance   8  3  5  0.375  3.4          63.7
# 569    1631376   Dmytro Skapintsev   2  0  2  0.000  1.1          75.0
# 570    1630606       Javonte Smart   1  1  0  1.000  0.7           0.0
# 571    1628382      Justin Jackson   2  2  0  1.000  0.4           0.0
#
#      E_DEF_RATING  E_NET_RATING  ...  E_OFF_RATING_RANK  E_DEF_RATING_RANK  \
# 0           155.1         -55.1  ...                514                570
# 1           121.0           6.2  ...                 10                546
# 2           102.5         -12.7  ...                548                 36
# 3            89.3           7.4  ...                527                 11
# 4           109.9          -4.8  ...                452                169
# ..            ...           ...  ...                ...                ...
# 567         115.2          15.6  ...                  6                425
# 568         112.3         -48.6  ...                568                287
# 569          87.2         -12.2  ...                566                  9
# 570         300.0        -300.0  ...                571                572
# 571           0.0           0.0  ...                571                  1
#
#      E_NET_RATING_RANK  E_AST_RATIO_RANK  E_OREB_PCT_RANK  E_DREB_PCT_RANK  \
# 0                  569                 1              545              557
# 1                  100               553               19              176
# 2                  510               376              398               59
# 3                   82               553               38              557
# 4                  363               282              163              285
# ..                 ...               ...              ...              ...
# 567                 20               115              121              479
# 568                565               553              545              271
# 569                502               553              545              557
# 570                572               553              545              557
# 571                252               553              545              557
#
#      E_REB_PCT_RANK  E_TOV_PCT_RANK  E_USG_PCT_RANK  E_PACE_RANK
# 0               561               1             569            1
# 1                88               1               4            2
# 2               143              48              22            3
# 3               508             572              33            4
# 4               220             541             227            5
# ..              ...             ...             ...          ...
# 567             296               1             183          568
# 568             431              48             410          569
# 569             561               1              70          570
# 570             561               1             569          571
# 571             561               1             569          572
#
# [572 rows x 32 columns]

# %%
def get_name(player_name):
    player = players.find_players_by_full_name(player_name)
    return player[0]['full_name']

# %%
get_name('lebron james')
# Out:
# 'LeBron James'

# %%
lbj = commonplayerinfo.CommonPlayerInfo(player_id=2544).get_data_frames()[0]

# %%
lbj['HEIGHT']
# Out:
# 0    6-9
# Name: HEIGHT, dtype: object
